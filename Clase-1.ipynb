# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

# %% [markdown]
# # Volumen de Datos generados en los ultimos 10 años

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 18,
        }
x = np.linspace(10, 17, 100)
x2 = np.linspace(15, 17, 100)
y = np.exp(x)

ix = np.linspace(10, 17)
iy = np.exp(ix)

verts = [(a, 0)] + list(zip(ix, iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor='0.5')

plt1, plt2 = plt.subplots()

plt1=plt.plot(x, y, 'k')
plt1=plt.title('Volumen de Datos Generado', fontdict=font)
plt1=plt.text(0, 20, r'Funcion Exponencial $y=e^x$', fontdict=font)

plt1=plt.xlabel('Año 2010-2017', fontdict=font)
plt1=plt.ylabel('Datos PetaBytes', fontdict=font)

# Tweak spacing to prevent clipping of ylabel
plt1=plt.subplots_adjust(left=0.15)

#plt1=plt.grid(True)
plt.show()
